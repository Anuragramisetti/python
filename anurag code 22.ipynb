# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_upload=pd.read_csv("dataset.csv")

# %%
data_upload
# Out:
#              Country Name Country Code  \
# 0             Afghanistan          AFG
# 1                 Albania          ALB
# 2    United Arab Emirates          ARE
# 3               Argentina          ARG
# 4                 Armenia          ARM
# ..                    ...          ...
# 98            Timor-Leste          TLS
# 99    Trinidad and Tobago          TTO
# 100               Tunisia          TUN
# 101               Turkiye          TUR
# 102               Ukraine          UKR
#
#                                         Indicator Name     Indicator Code  \
# 0    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 1    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 2    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 3    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 4    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# ...

# %%
data_upload.isnull().sum()
# Out:
# Country Name       0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 2001              77
# 2002              64
# 2003              57
# 2004              65
# 2005              49
# 2006              56
# 2007              36
# 2008              58
# 2009              55
# 2010              39
# 2011              59
# 2012              56
# 2013              42
# 2014              64
# 2015              68
# 2016              53
# 2017              63
# 2018              62
# 2019              65
# 2020              65
# dtype: int64

# %%
data_upload["2001"].fillna("1", inplace = True)

# %%
data_upload
# Out:
#              Country Name Country Code  \
# 0             Afghanistan          AFG
# 1                 Albania          ALB
# 2    United Arab Emirates          ARE
# 3               Argentina          ARG
# 4                 Armenia          ARM
# ..                    ...          ...
# 98            Timor-Leste          TLS
# 99    Trinidad and Tobago          TTO
# 100               Tunisia          TUN
# 101               Turkiye          TUR
# 102               Ukraine          UKR
#
#                                         Indicator Name     Indicator Code  \
# 0    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 1    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 2    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 3    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 4    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# ...

# %%
data_upload["2002"].fillna("1", inplace = True)
data_upload["2003"].fillna("1", inplace = True)
data_upload["2004"].fillna("1", inplace = True)
data_upload["2005"].fillna("1", inplace = True)
data_upload["2006"].fillna("1", inplace = True)
data_upload["2007"].fillna("1", inplace = True)
data_upload["2008"].fillna("1", inplace = True)
data_upload["2009"].fillna("1", inplace = True)
data_upload["2010"].fillna("1", inplace = True)
data_upload["2011"].fillna("1", inplace = True)
data_upload["2012"].fillna("1", inplace = True)
data_upload["2013"].fillna("1", inplace = True)
data_upload["2014"].fillna("1", inplace = True)
data_upload["2015"].fillna("1", inplace = True)
data_upload["2016"].fillna("1", inplace = True)
data_upload["2017"].fillna("1", inplace = True)
data_upload["2018"].fillna("1", inplace = True)
data_upload["2019"].fillna("1", inplace = True)
data_upload["2020"].fillna("1", inplace = True)

# %%
data_upload
# Out:
#              Country Name Country Code  \
# 0             Afghanistan          AFG
# 1                 Albania          ALB
# 2    United Arab Emirates          ARE
# 3               Argentina          ARG
# 4                 Armenia          ARM
# ..                    ...          ...
# 98            Timor-Leste          TLS
# 99    Trinidad and Tobago          TTO
# 100               Tunisia          TUN
# 101               Turkiye          TUR
# 102               Ukraine          UKR
#
#                                         Indicator Name     Indicator Code  \
# 0    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 1    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 2    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 3    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 4    Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# ...

# %%
data_upload.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
# dtype: int64

# %%
np.random.seed(42)
def true_gen(x):
    y = np.sin(1.2 * x * np.pi) 
    return(y)
x = np.sort(np.random.rand(120))
y = true_gen(x) + 0.1 * np.random.randn(len(x))

# %%
random_ind = np.random.choice(list(range(120)), size = 120, replace=False)
x_t = x[random_ind]
y_t = y[random_ind]
train = x_t[:int(0.7 * len(x))] 
test = x_t[int(0.7 * len(x)):]
y_train = y_t[:int(0.7 * len(y))]
y_test = y_t[int(0.7 * len(y)):]
x_linspace = np.linspace(0, 1, 1000)
y_true = true_gen(x_linspace)

# %%
plt.plot(train, y_train, 'ko', label = 'Train'); 
plt.plot(test, y_test, 'ro', label = 'Test')
plt.plot(x_linspace, y_true, 'b-', linewidth = 2, label = 'True function')
plt.legend()
plt.xlabel('x'); plt.ylabel('y'); plt.title('Data');

# %%
df=data_upload.drop(['Country Name','Country Code','Indicator Name','Indicator Code'], axis=1)

# %%
df
# Out:
#          2001       2002       2003       2004       2005       2006  \
# 0    5.668424   4.622149   7.259298   5.502361   5.840148   6.085466
# 1           1          1          1          1          1          1
# 2           1          1          1          1          1          1
# 3           1   1.053531          1          1          1          1
# 4           1          1          1          1          1   8.762241
# ..        ...        ...        ...        ...        ...        ...
# 98          1   8.599048          1          1          1          1
# 99          1          1          1   9.090909          1          1
# 100  3.642489   3.677148   3.556827   3.621567   3.623779   3.803794
# 101         1  12.658996  12.830922  12.654695  12.650705  12.878769
# 102  1.312794   1.763697   1.768589          1          1          1
#
#           2007       2008       2009       2010       2011       2012  \
# ...

# %%
X = df
y = df['2002']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2001    103 non-null    object
#  1   2002    103 non-null    object
#  2   2003    103 non-null    object
#  3   2004    103 non-null    object
#  4   2005    103 non-null    object
#  5   2006    103 non-null    object
#  6   2007    103 non-null    object
#  7   2008    103 non-null    object
#  8   2009    103 non-null    object
#  9   2010    103 non-null    object
#  10  2011    103 non-null    object
#  11  2012    103 non-null    object
#  12  2013    103 non-null    object
#  13  2014    103 non-null    object
#  14  2015    103 non-null    object
#  15  2016    103 non-null    object
#  16  2017    103 non-null    object
#  17  2018    103 non-null    object
#  18  2019    103 non-null    object
#  19  2020    103 non-null    object
# dtypes: object(20)
# memory usage: 16.2+ KB

# %%
X.head()
# Out:
#        2001      2002      2003      2004      2005      2006       2007  \
# 0  5.668424  4.622149  7.259298  5.502361  5.840148  6.085466   5.940385
# 1         1         1         1         1         1         1  17.426273
# 2         1         1         1         1         1         1          1
# 3         1  1.053531         1         1         1         1          1
# 4         1         1         1         1         1  8.762241   8.824705
#
#        2008       2009       2010       2011       2012       2013       2014  \
# 0  5.779478   4.843049   5.001187   5.391717   5.465576   5.518333   5.742548
# 1  9.991533  16.815117  17.023225  17.010824  17.039873  17.287964  12.756644
# 2         1          1  19.372929  18.301158  12.768782  20.927781  21.568627
# 3         1          1          1          1          1          1          1
# 4  8.906679    8.92172   8.945245   9.104293   9.174094    9.16221   9.198548
#
# ...

# %%
cols = X.columns

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
X = ms.fit_transform(X)

# %%
X = pd.DataFrame(X, columns=[cols])

# %%
X.head()
# Out:
#        2001      2002      2003      2004      2005      2006      2007  \
# 0  0.115654  0.091305  0.146778  0.105588  0.110528  0.114949  0.111992
# 1  0.018582  0.016987  0.020210  0.019171  0.018798  0.018889  0.328562
# 2  0.018582  0.016987  0.020210  0.019171  0.018798  0.018889  0.018840
# 3  0.018582  0.018085  0.020210  0.019171  0.018798  0.018889  0.018840
# 4  0.018582  0.016987  0.020210  0.019171  0.018798  0.165512  0.166377
#
#        2008      2009      2010      2011      2012      2013      2014  \
# 0  0.105706  0.068944  0.070342  0.077505  0.074825  0.075897  0.079017
# 1  0.182822  0.239465  0.239530  0.244569  0.233405  0.237897  0.175693
# 2  0.018202  0.014207  0.272598  0.263122  0.174886  0.287997  0.297150
# 3  0.018202  0.014207  0.014032  0.014359  0.013643  0.013706  0.013651
# 4  0.162960  0.127038  0.125847  0.130886  0.125636  0.126052  0.126652
#
#        2015      2016      2017      2018      2019      2020
# ...

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0) 
kmeans.fit(X)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# KMeans(n_clusters=2, random_state=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[0.0439278 , 0.0402027 , 0.05256843, 0.03958825, 0.04851662,
#         0.05037644, 0.06870494, 0.05373358, 0.04242796, 0.05458077,
#         0.04437518, 0.03908634, 0.04644519, 0.03716434, 0.0311188 ,
#         0.04370567, 0.03394522, 0.03944326, 0.03939869, 0.03156699],
#        [0.42698607, 0.45950372, 0.43263201, 0.47470637, 0.51861406,
#         0.54116579, 0.48854028, 0.42411723, 0.47038016, 0.47481486,
#         0.43224025, 0.41617945, 0.54102625, 0.55115772, 0.48354462,
#         0.50419441, 0.45436743, 0.45922868, 0.4556375 , 0.46456987]])

# %%
kmeans.inertia_
# Out:
# 26.635819193147743

# %%
labels = kmeans.labels_
correct_labels = sum(y == labels)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
# Out:
# Result: 0 out of 103 samples were correctly labeled.

# %%
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Accuracy score: 0.00
